# %%
import torch
import cv2
# Image Processing
import numpy as np
import matplotlib.pyplot as plt

# %%
# YOLOv5 model and utilites
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained = True)
# Load pre-trained YOLOv5s model
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-12-29 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
image = cv2.imread("jungle.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
results = model(image)

# %%
results.render()
# Display image with predicted bounding boxes and labels
plt.imsave('abc.jpg', np.squeeze(results.render()))
# Display using matplotlib

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x476>

# %%
# Acces individual detections for further processing
boxes = results.xyxy[0].tolist()
# Bounding boxes [x1, y1, x2, y2, confidence, class]
