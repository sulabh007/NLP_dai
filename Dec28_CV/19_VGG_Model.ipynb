# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

# %%
# load an image from file
image = load_img('Adolf-Hitler-1933.webp', target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Convert the image pixels to a numpy array
image = img_to_array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
# resahpe data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
# prepare the image for the VGG model
image = preprocess_input(image)

# %%
image;

# %%
# load the model
model = VGG16()

# %%
# predict the proababilty across all output classes
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 730ms/step

# %%
# convert the probality to class labels
label = decode_predictions(yhat)

# %%
label
# Out:
# [[('n03763968', 'military_uniform', 0.57200646),
#   ('n03942813', 'ping-pong_ball', 0.03406438),
#   ('n04350905', 'suit', 0.019996122),
#   ('n02883205', 'bow_tie', 0.019172344),
#   ('n04479046', 'trench_coat', 0.018691285)]]

# %%
# load an image from file
image = load_img('idli.jpg', target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Convert the image pixels to a numpy array
image = img_to_array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
# resahpe data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
# prepare the image for the VGG model
image = preprocess_input(image)

# %%
image;

# %%
# predict the proababilty across all output classes
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 607ms/step

# %%
# convert the probality to class labels
label = decode_predictions(yhat)

# %%
label
# Out:
# [[('n03259280', 'Dutch_oven', 0.34130335),
#   ('n03314780', 'face_powder', 0.15109524),
#   ('n03400231', 'frying_pan', 0.0933237),
#   ('n03775546', 'mixing_bowl', 0.0859689),
#   ('n04019541', 'puck', 0.052988503)]]

# %%
# load an image from file
image = load_img('pizza.jpg', target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Convert the image pixels to a numpy array
image = img_to_array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
# resahpe data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
# prepare the image for the VGG model
image = preprocess_input(image)

# %%
image;

# %%
# predict the proababilty across all output classes
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 581ms/step

# %%
# convert the probality to class labels
label = decode_predictions(yhat)

# %%
label
# Out:
# [[('n07873807', 'pizza', 0.999551),
#   ('n07684084', 'French_loaf', 9.644882e-05),
#   ('n07716906', 'spaghetti_squash', 6.055048e-05),
#   ('n07716358', 'zucchini', 4.7661106e-05),
#   ('n07717410', 'acorn_squash', 3.2272623e-05)]]
